# %% [markdown]
# # Plot of CO2 and CER of reactor 13-24 - Fed Batch fermentation

# %%
# %matplotlib inline
# %run functions.ipynb

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
R13 = pd.read_csv('data/fedbatch/R13.csv')
R14 = pd.read_csv('data/fedbatch/R14.csv')
R15 = pd.read_csv('data/fedbatch/R15.csv')
R16 = pd.read_csv('data/fedbatch/R16.csv')
R17 = pd.read_csv('data/fedbatch/R17.csv')
R18 = pd.read_csv('data/fedbatch/R18.csv')
R19 = pd.read_csv('data/fedbatch/R19.csv')
R20 = pd.read_csv('data/fedbatch/R20.csv')
R21 = pd.read_csv('data/fedbatch/R21.csv')
R22 = pd.read_csv('data/fedbatch/R22.csv')
R23 = pd.read_csv('data/fedbatch/R23.csv')
R23 = pd.read_csv('data/fedbatch/R24.csv')

# %%
print('Substrate conc = 6 g/L glycine, Feedrate = 0.03 unit?')
plot_cer_co2(R13, 13)
# Out:
# Substrate conc = 6 g/L Glycine, Feedrate = 0.03 ?

# %%
print('Substrate conc = 6 g/L glycine, Feedrate = 0.03 unit?')
plot_cer_co2(R14, 14)
# Out:
# Substrate conc = 6 g/L glycine, Feedrate = 0.03 unit?

# %%
print('Substrate conc = 6 g/L lycine, Feedrate = 0.05 unit?') 
plot_cer_co2(R15, 15)
# Out:
# Substrate conc = 6 g/L lycine, Feedrate = 0.05 unit?
