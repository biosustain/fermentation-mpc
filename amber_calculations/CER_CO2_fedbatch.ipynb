# %% [markdown]
# # Plot of CO2 and CER of reactor 13-24 - Fed Batch fermentation

# %%
# %matplotlib inline
# %run functions.ipynb

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
R13 = pd.read_csv('data/fedbatch/R13.csv', index_col = 0)
R14 = pd.read_csv('data/fedbatch/R14.csv', index_col = 0)
R15 = pd.read_csv('data/fedbatch/R15.csv', index_col = 0)
R16 = pd.read_csv('data/fedbatch/R16.csv', index_col = 0)
R17 = pd.read_csv('data/fedbatch/R17.csv', index_col = 0)
R18 = pd.read_csv('data/fedbatch/R18.csv', index_col = 0)
R19 = pd.read_csv('data/fedbatch/R19.csv', index_col = 0)
R20 = pd.read_csv('data/fedbatch/R20.csv', index_col = 0)
R21 = pd.read_csv('data/fedbatch/R21.csv', index_col = 0)
R22 = pd.read_csv('data/fedbatch/R22.csv', index_col = 0)
R23 = pd.read_csv('data/fedbatch/R23.csv', index_col = 0)
R24 = pd.read_csv('data/fedbatch/R24.csv', index_col = 0)

# %%
print('Substrate conc = 6 g/L glycine, Feedrate = 0.03 mL/h')
data_frame_selected_values_R13, mu_R13 = calculate_mu(R13, 13)
plot_cer_co2(data_frame_selected_values_R13, 13)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R13, mu_R13)
plot_mu_smaller_interval(data_frame_selected_values_R13, mu_R13)
# Out:
# Substrate conc = 6 g/L glycine, Feedrate = 0.03 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 6 g/L glycine, Feedrate = 0.03 mL/h')
data_frame_selected_values_R14, mu_R14 = calculate_mu(R14, 14)
plot_cer_co2(data_frame_selected_values_R14, 14)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R14, mu_R14)
plot_mu_smaller_interval(data_frame_selected_values_R14, mu_R14)
# Out:
# Substrate conc = 6 g/L glycine, Feedrate = 0.03 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 6 g/L lycine, Feedrate = 0.05 mL/h') 
data_frame_selected_values_R15, mu_R15 = calculate_mu(R15, 15)
plot_cer_co2(data_frame_selected_values_R15, 15)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R15, mu_R15)
plot_mu_smaller_interval(data_frame_selected_values_R15, mu_R15)
# Out:
# Substrate conc = 6 g/L lycine, Feedrate = 0.05 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 6 g/L lycine, Feedrate = 0.05 mL/h')
data_frame_selected_values_R16, mu_R16 = calculate_mu(R16, 16)
plot_cer_co2(data_frame_selected_values_R16, 16)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R16, mu_R16)
plot_mu_smaller_interval(data_frame_selected_values_R16, mu_R16)
# Out:
# Substrate conc = 6 g/L lycine, Feedrate = 0.05 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 6 g/L lycine, Feedrate = 0.02 mL/h')
data_frame_selected_values_R17, mu_R17 = calculate_mu(R17, 17)
plot_cer_co2(data_frame_selected_values_R17, 17)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R17, mu_R17)
plot_mu_smaller_interval(data_frame_selected_values_R17, mu_R17)
# Out:
# Substrate conc = 6 g/L lycine, Feedrate = 0.02 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 6 g/L lycine, Feedrate = 0.02 mL/h')
data_frame_selected_values_R18, mu_R18 = calculate_mu(R18, 18)
plot_cer_co2(data_frame_selected_values_R18, 18)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R18, mu_R18)
plot_mu_smaller_interval(data_frame_selected_values_R18, mu_R18)
# Out:
# Substrate conc = 6 g/L lycine, Feedrate = 0.02 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 4 g/L lycine, Feedrate = 0.03 mL/h')
data_frame_selected_values_R19, mu_R19 = calculate_mu(R19, 19)
plot_cer_co2(data_frame_selected_values_R19, 19)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R19, mu_R19)
plot_mu_smaller_interval(data_frame_selected_values_R19, mu_R19)
# Out:
# Substrate conc = 4 g/L lycine, Feedrate = 0.03 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 4 g/L lycine, Feedrate = 0.03 mL/h')
data_frame_selected_values_R20, mu_R20 = calculate_mu(R20, 20)
plot_cer_co2(data_frame_selected_values_R20, 20)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R20, mu_R20)
plot_mu_smaller_interval(data_frame_selected_values_R20, mu_R20)
# Out:
# Substrate conc = 4 g/L lycine, Feedrate = 0.03 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 4 g/L lycine, Feedrate = 0.05 mL/h')
data_frame_selected_values_R21, mu_R21 = calculate_mu(R21, 21)
plot_cer_co2(data_frame_selected_values_R21, 21)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R21, mu_R21)
plot_mu_smaller_interval(data_frame_selected_values_R21, mu_R21)
# Out:
# Substrate conc = 4 g/L lycine, Feedrate = 0.05 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 4 g/L lycine, Feedrate = 0.05 mL/h')
data_frame_selected_values_R22, mu_R22 = calculate_mu(R22, 22)
plot_cer_co2(data_frame_selected_values_R22, 22)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R22, mu_R22)
plot_mu_smaller_interval(data_frame_selected_values_R22, mu_R22)
# Out:
# Substrate conc = 4 g/L lycine, Feedrate = 0.05 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 4 g/L lycine, Feedrate = 0.02 mL/h')
data_frame_selected_values_R23, mu_R23 = calculate_mu(R23, 23)
plot_cer_co2(data_frame_selected_values_R23, 23)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R23, mu_R23)
plot_mu_smaller_interval(data_frame_selected_values_R23, mu_R23)
# Out:
# Substrate conc = 4 g/L lycine, Feedrate = 0.02 mL/h
# The time 0 below correspondt to the time where CER values begin

# %%
print('Substrate conc = 4 g/L lycine, Feedrate = 0.02 mL/h')
data_frame_selected_values_R24, mu_R24 = calculate_mu(R24, 24)
plot_cer_co2(data_frame_selected_values_R24, 24)
print('The time 0 below correspondt to the time where CER values begin')
plot_mu(data_frame_selected_values_R24, mu_R24)
plot_mu_smaller_interval(data_frame_selected_values_R24, mu_R24)
# Out:
# Substrate conc = 4 g/L lycine, Feedrate = 0.02 mL/h
# The time 0 below correspondt to the time where CER values begin
